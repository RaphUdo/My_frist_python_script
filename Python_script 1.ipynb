# %%
print("Hello, my name is Raphael James and I am new to Python")
# Out:
# Hello, my name is Raphael James and I am new to Python

# %%
print("this is my first python code")
# Out:
# this is my first python code

# %%
print("Literature adds to reality, it does not simply describe it.\n It enriches the necessary competencies that daily life requires and provides;\n and in this respect, it irrigates the deserts that our lives have already become.")
# Out:
# Literature adds to reality, it does not simply describe it.
#  It enriches the necessary competencies that daily life requires and provides;
#  and in this respect, it irrigates the deserts that our lives have already become.

# %%
print("My name \\is Raphael")
# Out:
# My name \is Raphael

# %%
print("She said \'I didn't do it\' in a angry tone")
# Out:
# She said 'I didn't do it' in a angry tone

# %%
import math

# %%
round(math.log2(100),2)
# Out:
# 6.64

# %%
number_1= 6

# %%
number_2= 100

# %%
(number_1+number_2)
# Out:
# 106

# %%
#Excercise1
num1=30
num2=55
sum=num1*num2
print("The summ of the 2 numbers is:",sum)
# Out:
# The summ of the 2 numbers is: 1650

# %%
my_name= "Raphael"
print(my_name)
print(type(my_name))
len(my_name)
# Out:
# Raphael
# <class 'str'>
# 7

# %%
num1= int(input('give me a first number'))
num2= int(input('give me a second number'))
sum=num1+num2
print(sum)
# Out:
# give me a first number10
# give me a second number23
# 33

# %%
user_name= int(input('What is your name?'))
user_age= int(input('How old are you?'))
# Out:
# What is your name?4
# How old are you?20

# %%
yourName= input('What is your name?')
yourAge= input('How old are you?')
print('The winners name is', yourName, 'and they are',yourAge)
# Out:
# What is your name?RJ
# How old are you?20
# The winners name is RJ and they are 20

# %%
a= int(input('null1?'))
b= int(input('null2?'))
# Out:
# null1?20
# null2?100

# %%
if b>a:
  print('True')
# Out:
# True

# %%
number = float(input('Enter a number:'))
# Out:
# Enter a number:10

# %%
number = int(input('Enter a number:'))
if number > 0:
  print('Positive')
  if number < 0:
    print('Negative')
# Out:
# Enter a number:-4

# %%
num1= int(input("Write a number"))
if num1 < 0:
  print("Negative")
elif num1 > 0:
    print("Positive")
else:
      print("Number is 0")
# Out:
# Write a number40
# Positive

# %%
number= int(input("Enter a number:"))
if number % 2 == 0:
  print("The number is even.")
else :
    print("The number is odd.")
# Out:
# Enter a number:43
# The number is odd.

# %%
i= 1
while i<10:
  i=i+1
  if i% 2 != 0:
print(i)
# Out:
#   File "<ipython-input-17-4f17d7efc201>", line 5
#     print(i)
#             ^
# IndentationError: expected an indented block after 'if' statement on line 4

# %%
import random

# %%
fruits= ["apple", "banana", "berry"]

# %%
for number in range (1,51,3):
  print(number)
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19
# 22
# 25
# 28
# 31
# 34
# 37
# 40
# 43
# 46
# 49

# %%
for number in range(1,100,1):
  if number%3==0 and number%5==0:
    print("FizzBuzz")
  elif number % 3 == 0:
    print("Fizz")
  elif number % 5 == 0:
    print("Buzz")
  else:
    print(number)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz

# %%
try:
    num1=float(input('Enter the first number: '))
    num2=float(input('Enter value 2: '))
    operation = input("choose an arithmetic operation(+,-,*,/): ")
    if operation == "+":
      result = num1+num2
    print(f"The result of {num1}+{num2} is {result}")
      elif: operation = '-'
    result = num1 - num2
    print(f"The result of {num1}-{num2} is {result}")
elif: operation == '*'
result = num1*num2
print(f"The result of {num1}*{num2} is {result}")
  elif: operation == '/'
      if
      num2 == 0:
      print("Division by zero is not allowed")
      else:
      result = num1/num2
      print(f"The result of {num1}/{num2} is {result}")
      else:
        print("invalid operation. Please choose +,-,*,or /.")
# Out:
#   File "<ipython-input-21-4fb18fe94bf9>", line 8
#     elif: operation = '-'
#     ^
# IndentationError: unexpected indent

# %% [markdown]
# # New section

# %%
dictionary = {"brand": "Ford", "model": "Mustang", "year": 1964 }

# %%
print(dictionary["brand"])
print(dictionary["model"])
print(dictionary["year"])
# Out:
# Ford
# Mustang
# 1964

# %%
my_name= "Desola"
my_age= 22
my_email= "desola@gmail.com"

# %%
print(my_name)
print(my_age)
print(my_email)
# Out:
# Desola
# 22
# desola@gmail.com

# %%
x='hello'[0]
